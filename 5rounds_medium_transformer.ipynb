# %%
import os
import sys

# %%
def iterate_over_files_in_directory(directory):
    for file_name in os.listdir(directory):
        if file_name.endswith(".csv"):  # You can adjust the file extension if needed
            file_path = os.path.join(directory, file_name)
            yield file_path

# %%
import os
import csv

# %%
import json
import warnings
import numpy as np
import csv
csv.field_size_limit(100000000)
# Out:
# 131072

# %%
path = os.path.abspath('')+'/train'
y = []
X2 = []
LABELS = {"enterprise": 0, "cable": 1, "fiber": 2, "hotspot": 3, "eduroam": 4}

# %%
from collections import defaultdict
TCP_FLAG_VOCAB = ["SYN", "ACK", "FIN", "PSH", "RST", "URG", "ECE", "CWR"]
FLAG_TO_IDX = {f: i for i, f in enumerate(TCP_FLAG_VOCAB)}
K_FLAGS = len(TCP_FLAG_VOCAB)
def flags_to_multihot(flag_str, vocab=FLAG_TO_IDX):
    vec = np.zeros(len(vocab), dtype=np.float32)
    if not flag_str or flag_str == "NONE":
        return vec
    parts = flag_str.upper().replace(" ", "").split("+")
    for p in parts:
        if p in vocab:
            vec[vocab[p]] = 1.0
    return vec
def _parse_semicolon_list(s, cast=float):
    """Parse a semicolon-separated string into a list with type cast.
    Empty cells or '' return [].
    """
    if s is None:
        return []
    s = s.strip()
    if not s:
        return []
    parts = s.split(";")
    out = []
    for p in parts:
        p = p.strip()
        if p == "":
            # treat empty entries as missing; skip
            continue
        try:
            out.append(cast(p))
        except Exception:
            # if cast fails, skip that element
            continue
    return out

def traffic_csv_converter2(file_path, access_network, target_len=20):
    PAD_VAL = np.nan  # best for XGBoost (native missing handling)

    with open(file_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        rows = list(reader)

    if not rows:
        return

    X_list, y_list = [], []

    for row in rows:
        # --- dst_port parsing (keep your original behavior) ---
        try:
            dst_port = int(row.get("dst_ip") and row.get("dst_port") or row["dst_port"])
        except Exception:
            continue

        # skip DNS
        if dst_port == 53:
            continue

        # proto flag (not used below unless you add it as a feature)
        proto = (row.get("proto") or "").upper().strip()
        is_tcp = 1 if proto == "TCP" else 0

        # --- timestamps ---
        ts_sec = _parse_semicolon_list(row.get("timestamps"), cast=float)
        if not ts_sec:
            continue

        ts_ms = np.array(ts_sec, dtype=np.float64) * 1e3

        # remove flows with only 1 packet (or 0)
        if ts_ms.size <= 1:
            continue

        # inter-arrival times (ms)
        iats = np.diff(ts_ms, prepend=ts_ms[0])
        iats[0] = 0.0

        # --- sizes ---
        sizes_list = _parse_semicolon_list(row.get("ip_sizes"), cast=float)
        if len(sizes_list) == 0:
            sizes = np.zeros_like(ts_ms)
        else:
            sizes = np.array(sizes_list, dtype=np.float64)

            # align lengths; if same length, reorder; else trim/pad to match ts_ms
            if len(sizes) == len(ts_ms):
                sizes = sizes
            else:
                sizes = sizes[:len(ts_ms)]
                if len(sizes) < len(ts_ms):
                    sizes = np.pad(
                        sizes,
                        (0, len(ts_ms) - len(sizes)),
                        constant_values=0.0
                    )

        # --- truncate/pad to target_len ---
        L = min(len(ts_ms), target_len)

        feat_iat = iats[:L]
        feat_sz  = sizes[:L]

        if L < target_len:
            pad = target_len - L
            feat_iat = np.pad(feat_iat, (0, pad), constant_values=PAD_VAL)  # NaN pad
            feat_sz  = np.pad(feat_sz,  (0, pad), constant_values=PAD_VAL)  # NaN pad

        # (target_len, 2)
        sample = np.stack([feat_iat, feat_sz], axis=1)
        X_list.append(sample)
        y_list.append(LABELS[access_network])

    if not X_list:
        return

    X2.extend(X_list)
    y.extend(y_list)

# %%
ethernet_path = path + "/enterprise"
for file_path in iterate_over_files_in_directory(ethernet_path):
        traffic_csv_converter2(file_path,"enterprise")
modem_path = path + "/cable"
for file_path in iterate_over_files_in_directory(modem_path):
        traffic_csv_converter2(file_path,"cable")
fiber_path = path + "/fiber"
for file_path in iterate_over_files_in_directory(fiber_path):
        traffic_csv_converter2(file_path,"fiber")
hotspot_path = path + "/hotspot"
for file_path in iterate_over_files_in_directory(hotspot_path):
        traffic_csv_converter2(file_path,"hotspot")
# eduroam_path = path + "/eduroam"
# for file_path in iterate_over_files_in_directory(eduroam_path):
#         traffic_csv_converter2(file_path,"eduroam")

# %%
y=np.array(y)
X2=np.array(X2)

# %%
X2.shape
# Out:
# (139915, 20, 2)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_val,y_train, y_val = train_test_split(
#     X2,
#     y,
#     test_size=0.2,
#     random_state=42,
#     shuffle=True
# )

# %%
import copy
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight


class TimeSeriesTransformer(nn.Module):
    def __init__(
        self,
        input_dim: int,
        num_classes: int,
        seq_len: int = 20,
        model_dim: int = 128,
        num_layers: int = 2,
        nhead: int = 4,
    ):
        super().__init__()
        self.seq_len = seq_len
        self.input_proj = nn.Linear(input_dim, model_dim)
        self.input_ln = nn.LayerNorm(model_dim)
        self.pos_emb = nn.Parameter(torch.zeros(1, seq_len, model_dim))
        nn.init.normal_(self.pos_emb, mean=0.0, std=0.02)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=nhead,
            dim_feedforward=512,
            dropout=0.1,
            activation="relu",
            batch_first=True,
            norm_first=False,
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)

        self.attn_pool = nn.Linear(model_dim, 1)
        self.classifier = nn.Linear(model_dim, num_classes)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        if x.size(1) != self.seq_len:
            raise ValueError(f"Expected seq_len={self.seq_len}, got {x.size(1)}")

        padding_mask = torch.isnan(x).any(dim=-1)
        x = torch.nan_to_num(x, nan=0.0)
        x = self.input_proj(x)
        x = self.input_ln(x)
        x = x + self.pos_emb[:, :x.size(1)]
        x = self.encoder(x, src_key_padding_mask=padding_mask)
        scores = self.attn_pool(x).squeeze(-1)
        scores = scores.masked_fill(padding_mask, -1e9)
        weights = torch.softmax(scores, dim=1)
        pooled = (x * weights.unsqueeze(-1)).sum(dim=1)

        return self.classifier(pooled)

def make_loaders(X, y, batch_size=64, test_size=0.2, seed=42):
    X_train, X_val, y_train, y_val = train_test_split(
        X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y
    )

    X_train_t = torch.tensor(X_train, dtype=torch.float32)
    y_train_t = torch.tensor(y_train, dtype=torch.long)
    X_val_t = torch.tensor(X_val, dtype=torch.float32)
    y_val_t = torch.tensor(y_val, dtype=torch.long)

    train_loader = DataLoader(TensorDataset(X_train_t, y_train_t), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(TensorDataset(X_val_t, y_val_t), batch_size=max(64, batch_size), shuffle=False)

    return (X_train, y_train, X_val, y_val, train_loader, val_loader)


def compute_balanced_weights(y_train):
    classes = np.unique(y_train)
    w = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
    num_classes = int(classes.max()) + 1
    full = np.zeros(num_classes, dtype=np.float32)
    for c, wc in zip(classes, w):
        full[int(c)] = float(wc)
    return full


def train_model(
    model,
    train_loader,
    val_loader,
    class_weights,
    epochs=50,
    device=None,
    patience=10,
    monitor="val_acc",
    save_path="best_model.pt",
    lr=3e-4,
    label_smoothing=0.1
):
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    w = torch.tensor(class_weights, dtype=torch.float32, device=device)
    criterion = nn.CrossEntropyLoss(weight=w, label_smoothing=label_smoothing)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

    best_score = None
    best_state = None
    epochs_no_improve = 0

    def improved(curr, best):
        if best is None:
            return True
        return curr > best if monitor == "val_acc" else curr < best

    for epoch in range(1, epochs + 1):
        # ---- train ----
        model.train()
        total_correct = 0
        total_n = 0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)

            logits = model(xb)
            loss = criterion(logits, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            preds = logits.argmax(dim=1)
            total_correct += (preds == yb).sum().item()
            total_n += xb.size(0)

        train_acc = total_correct / max(1, total_n)

        # ---- validate ----
        model.eval()
        v_correct = 0
        v_n = 0
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                preds = model(xb).argmax(dim=1)
                v_correct += (preds == yb).sum().item()
                v_n += xb.size(0)

        val_acc = v_correct / max(1, v_n)
        print(f"Epoch {epoch:02d} | train acc {train_acc:.4f} | val acc {val_acc:.4f}")

        if improved(val_acc, best_score):
            best_score = val_acc
            best_state = copy.deepcopy(model.state_dict())
            torch.save(best_state, save_path)
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= patience:
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    return model

# %%
X_test = []
y_test = []

# %%
def test_traffic_csv_converter(file_path, access_network, target_len=20):
    PAD_VAL = np.nan  # best for XGBoost (native missing handling)

    with open(file_path, "r", newline="") as f:
        reader = csv.DictReader(f)
        rows = list(reader)

    if not rows:
        return

    X_list, y_list = [], []

    for row in rows:
        # --- dst_port parsing (keep your original behavior) ---
        try:
            dst_port = int(row.get("dst_ip") and row.get("dst_port") or row["dst_port"])
        except Exception:
            continue

        # skip DNS
        if dst_port == 53:
            continue

        # proto flag (not used below unless you add it as a feature)
        proto = (row.get("proto") or "").upper().strip()
        is_tcp = 1 if proto == "TCP" else 0

        # --- timestamps ---
        ts_sec = _parse_semicolon_list(row.get("timestamps"), cast=float)
        if not ts_sec:
            continue

        ts_ms = np.array(ts_sec, dtype=np.float64) * 1e3

        # remove flows with only 1 packet
        if ts_ms.size <= 1:
            continue

        # inter-arrival times (ms)
        iats = np.diff(ts_ms, prepend=ts_ms[0])
        iats[0] = 0.0

        # --- sizes ---
        sizes_list = _parse_semicolon_list(row.get("ip_sizes"), cast=float)
        if len(sizes_list) == 0:
            sizes = np.zeros_like(ts_ms)
        else:
            sizes = np.array(sizes_list, dtype=np.float64)

            # align lengths; if same length, reorder; else trim/pad to match ts_ms
            if len(sizes) == len(ts_ms):
                sizes = sizes
            else:
                sizes = sizes[:len(ts_ms)]
                if len(sizes) < len(ts_ms):
                    sizes = np.pad(
                        sizes,
                        (0, len(ts_ms) - len(sizes)),
                        constant_values=0.0
                    )

        # --- truncate/pad to target_len ---
        L = min(len(ts_ms), target_len)

        feat_iat = iats[:L]
        feat_sz  = sizes[:L]

        if L < target_len:
            pad = target_len - L
            feat_iat = np.pad(feat_iat, (0, pad), constant_values=PAD_VAL)  # NaN pad
            feat_sz  = np.pad(feat_sz,  (0, pad), constant_values=PAD_VAL)  # NaN pad

        # (target_len, 2)
        sample = np.stack([feat_iat, feat_sz], axis=1)
        X_list.append(sample)
        y_list.append(LABELS[access_network])

    if not X_list:
        return

    X_test.extend(X_list)
    y_test.extend(y_list)

# %%
path = os.path.abspath('')+'/test'
ethernet_path = path + "/enterprise"
for file_path in iterate_over_files_in_directory(ethernet_path):
        test_traffic_csv_converter(file_path,"enterprise")
modem_path = path + "/cable"
for file_path in iterate_over_files_in_directory(modem_path):
        test_traffic_csv_converter(file_path,"cable")
fiber_path = path + "/fiber"
for file_path in iterate_over_files_in_directory(fiber_path):
        test_traffic_csv_converter(file_path,"fiber")
hotspot_path = path + "/hotspot"
for file_path in iterate_over_files_in_directory(hotspot_path):
        test_traffic_csv_converter(file_path,"hotspot")

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
import os
import time
import random
import numpy as np
import torch

from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
)

def set_all_seeds(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

@torch.no_grad()
def predict_numpy(model, X_np, batch_size: int = 256, device=None):
    device = device or ("cuda" if torch.cuda.is_available() else "cpu")
    model.eval().to(device)

    if torch.is_tensor(X_np):
        X_t = X_np.detach().to(dtype=torch.float32, device="cpu")
    else:
        X_t = torch.as_tensor(X_np, dtype=torch.float32, device="cpu")

    loader = torch.utils.data.DataLoader(
        torch.utils.data.TensorDataset(X_t),
        batch_size=batch_size,
        shuffle=False
    )

    preds = []
    for (xb,) in loader:
        xb = xb.to(device, non_blocking=True)
        logits = model(xb)
        preds.append(logits.argmax(dim=1).cpu().numpy())
    return np.concatenate(preds, axis=0)
def _to_numpy(X):
    """Convert torch.Tensor -> np.ndarray, otherwise return np.asarray(X)."""
    if torch.is_tensor(X):
        return X.detach().cpu().numpy()
    return np.asarray(X)
    
def infer_pkt_count_from_X(X, target_len=20, iat_feature_idx=0):
    """
    Returns pkt_count as shape [N] (int32), for both:
      - flat X:   [N, 2*target_len]  (IAT every other col starting at 0)
      - seq  X:   [N, target_len, 2] (IAT in feature channel iat_feature_idx)
    """
    X = _to_numpy(X)

    if X.ndim == 2:
        # flat: [N, 2*target_len]
        iat_cols = X[:, 0:2 * target_len:2]
        return np.sum(~np.isnan(iat_cols), axis=1).astype(np.int32)

    if X.ndim == 3:
        # sequence: [N, T, F]
        # count along time axis for the IAT feature channel
        iat = X[:, :target_len, iat_feature_idx]
        return np.sum(~np.isnan(iat), axis=1).astype(np.int32)

    raise ValueError(f"Unsupported X.ndim={X.ndim}, expected 2 or 3")


def mask_to_first_k_packets(X, k, target_len=20):
    """
    Masks packets > k to NaN.
    Works for:
      - flat X: [N, 2*target_len]
      - seq  X: [N, target_len, 2]
    """
    Xn = _to_numpy(X)
    Xk = np.array(Xn, copy=True)

    if Xk.ndim == 2:
        Xk[:, 2 * k:2 * target_len] = np.nan
        return Xk

    if Xk.ndim == 3:
        Xk[:, k:target_len, :] = np.nan
        return Xk

    raise ValueError(f"Unsupported X.ndim={Xk.ndim}, expected 2 or 3")


def selective_metrics_by_length(model, X, y, pkt_count, k_values=range(2, 21), device=None):
    """
    For each k:
      - keep samples with pkt_count >= k
      - DO NOT truncate/mask; use X as-is for kept flows
    Safe indexing for numpy or torch tensors.
    """
    pkt_count = np.asarray(pkt_count).reshape(-1)  # force [N]
    out = []

    for k in k_values:
        keep = pkt_count >= k
        coverage = float(keep.mean())
        keep_idx = np.flatnonzero(keep)
        n_kept = int(keep_idx.size)

        if n_kept == 0:
            out.append(dict(
                k=k, coverage=coverage, n_kept=0,
                acc=np.nan, macro_f1=np.nan, weighted_f1=np.nan,
                macro_precision=np.nan, macro_recall=np.nan
            ))
            continue

        # index only along the sample dimension (dim 0), works for np or torch
        X_keep = X[keep_idx]
        yt = y[keep_idx]

        yp = predict_numpy(model, X_keep, batch_size=256, device=device)

        out.append(dict(
            k=k,
            coverage=coverage,
            n_kept=n_kept,
            acc=float(accuracy_score(yt, yp)),
            macro_f1=float(f1_score(yt, yp, average="macro")),
            weighted_f1=float(f1_score(yt, yp, average="weighted")),
            macro_precision=float(precision_score(yt, yp, average="macro", zero_division=0)),
            macro_recall=float(recall_score(yt, yp, average="macro", zero_division=0)),
        ))

    return out

def run_one(seed, X2, y, X_test, y_test, save_dir="runs_transformer_5seeds", target_len=20):  # target_len ADDED
    os.makedirs(save_dir, exist_ok=True)
    set_all_seeds(seed)

    # 1) train/val split changes with seed
    X_train, y_train, X_val, y_val, train_loader, val_loader = make_loaders(
        X2, y, batch_size=64, test_size=0.2, seed=42
    )
    class_weights = compute_balanced_weights(y_train)

    # 2) new model each run
    model = TimeSeriesTransformer(
        input_dim=2,
        num_classes=4,
        seq_len=20,
    )

    # device for accurate timing
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # 3) train (early stopping on val_acc) + TIME IT
    if device == "cuda":
        torch.cuda.synchronize()
    t0 = time.perf_counter()

    model = train_model(
        model,
        train_loader,
        val_loader,
        class_weights,
        epochs=100,
        patience=5,
        monitor="val_acc",
        save_path=os.path.join(save_dir, f"best_model_seed{seed}.pt"),
        lr=3e-4,
    )

    if device == "cuda":
        torch.cuda.synchronize()
    train_time_s = time.perf_counter() - t0

    # 4) Evaluate on VAL + TIME IT
    if device == "cuda":
        torch.cuda.synchronize()
    t1 = time.perf_counter()

    y_val_pred = predict_numpy(model, X_val, batch_size=256, device=device)

    if device == "cuda":
        torch.cuda.synchronize()
    val_infer_time_s = time.perf_counter() - t1

    val_metrics = {
        "acc": float(accuracy_score(y_val, y_val_pred)),
        "macro_f1": float(f1_score(y_val, y_val_pred, average="macro")),
        "weighted_f1": float(f1_score(y_val, y_val_pred, average="weighted")),
        "macro_precision": float(precision_score(y_val, y_val_pred, average="macro", zero_division=0)),
        "macro_recall": float(recall_score(y_val, y_val_pred, average="macro", zero_division=0)),
        "cm": confusion_matrix(y_val, y_val_pred),
        "infer_time_s": float(val_infer_time_s),
        "infer_time_per_sample_ms": float(1000.0 * val_infer_time_s / max(1, len(X_val))),
    }

    # 5) Evaluate on TEST (fixed external set) + TIME IT
    if device == "cuda":
        torch.cuda.synchronize()
    t2 = time.perf_counter()

    y_test_pred = predict_numpy(model, X_test, batch_size=256, device=device)

    if device == "cuda":
        torch.cuda.synchronize()
    test_infer_time_s = time.perf_counter() - t2

    test_metrics = {
        "acc": float(accuracy_score(y_test, y_test_pred)),
        "macro_f1": float(f1_score(y_test, y_test_pred, average="macro")),
        "weighted_f1": float(f1_score(y_test, y_test_pred, average="weighted")),
        "macro_precision": float(precision_score(y_test, y_test_pred, average="macro", zero_division=0)),
        "macro_recall": float(recall_score(y_test, y_test_pred, average="macro", zero_division=0)),
        "cm": confusion_matrix(y_test, y_test_pred),
        "infer_time_s": float(test_infer_time_s),
        "infer_time_per_sample_ms": float(1000.0 * test_infer_time_s / max(1, len(X_test))),
    }
    pkt_val = infer_pkt_count_from_X(X_val, target_len=target_len)
    pkt_test = infer_pkt_count_from_X(X_test, target_len=target_len)

    val_metrics["length_sweep"] = selective_metrics_by_length(
    model,
    X_val,
    y_val,
    pkt_val,
    k_values=range(2, target_len + 1),
    device=device
    )
    test_metrics["length_sweep"] = selective_metrics_by_length(
        model,
        X_test,
        y_test,
        pkt_test,
        k_values=range(2, target_len + 1),
        device=device
    )

    return {
        "seed": int(seed),
        "train_time_s": float(train_time_s),
        "val": val_metrics,
        "test": test_metrics,
    }


def summarize(results, split="test"):
    metric_keys = ["acc", "macro_f1", "weighted_f1", "macro_precision", "macro_recall"]

    print(f"\n=== Per-run {split.upper()} metrics + inference time ===")
    for r in results:
        m = r[split]
        print(
            f"seed={r['seed']} | "
            f"acc={m['acc']:.4f} | "
            f"macro_f1={m['macro_f1']:.4f} | "
            f"weighted_f1={m['weighted_f1']:.4f} | "
            f"infer_time={m['infer_time_s']:.3f}s | "
            f"per_sample={m['infer_time_per_sample_ms']:.3f}ms"
        )

    # training time summary
    train_times = np.array([r["train_time_s"] for r in results], dtype=np.float64)
    print(f"\n=== TRAIN time Mean ± Std over {len(results)} runs ===")
    if len(train_times) > 1:
        print(f"train_time_s      : {train_times.mean():.3f} ± {train_times.std(ddof=1):.3f}")
    else:
        print(f"train_time_s      : {train_times.mean():.3f}")

    # metrics summary
    print(f"\n=== {split.upper()} Mean ± Std over {len(results)} runs ===")
    for k in metric_keys:
        vals = np.array([r[split][k] for r in results], dtype=np.float64)
        if len(vals) > 1:
            print(f"{k:16s}: {vals.mean():.4f} ± {vals.std(ddof=1):.4f}")
        else:
            print(f"{k:16s}: {vals.mean():.4f}")

    # inference time summary
    infer_times = np.array([r[split]["infer_time_s"] for r in results], dtype=np.float64)
    per_sample = np.array([r[split]["infer_time_per_sample_ms"] for r in results], dtype=np.float64)

    print(f"\n=== {split.upper()} INFERENCE time Mean ± Std over {len(results)} runs ===")
    if len(infer_times) > 1:
        print(f"infer_time_s      : {infer_times.mean():.3f} ± {infer_times.std(ddof=1):.3f}")
        print(f"per_sample_ms     : {per_sample.mean():.3f} ± {per_sample.std(ddof=1):.3f}")
    else:
        print(f"infer_time_s      : {infer_times.mean():.3f}")
        print(f"per_sample_ms     : {per_sample.mean():.3f}")

    # confusion matrices
    cms = np.stack([r[split]["cm"] for r in results], axis=0)
    print(f"\n{split.upper()} confusion matrix mean:\n", cms.mean(axis=0))
    if cms.shape[0] > 1:
        print(f"\n{split.upper()} confusion matrix std:\n", cms.std(axis=0, ddof=1))

def summarize_length_sweeps(results, split="test", target_len=20):
    print(f"\n=== {split.upper()} Length Sweep Mean ± Std ===")
    for k in range(2, target_len + 1):
        rows = [next(r for r in res[split]["length_sweep"] if r["k"] == k) for res in results]

        cov = np.array([r["coverage"] for r in rows], dtype=np.float64)
        acc = np.array([r["acc"] for r in rows], dtype=np.float64)
        mf1 = np.array([r["macro_f1"] for r in rows], dtype=np.float64)
        wf1 = np.array([r["weighted_f1"] for r in rows], dtype=np.float64)

        print(
            f"k={k:2d} | "
            f"coverage={np.nanmean(cov):.4f}±{np.nanstd(cov, ddof=1):.4f} | "
            f"acc={np.nanmean(acc):.4f}±{np.nanstd(acc, ddof=1):.4f} | "
            f"macro_f1={np.nanmean(mf1):.4f}±{np.nanstd(mf1, ddof=1):.4f} | "
            f"weighted_f1={np.nanmean(wf1):.4f}±{np.nanstd(wf1, ddof=1):.4f}"
        )

seeds = [0, 1, 2, 3, 4]
results = [run_one(s, X2, y, X_test, y_test) for s in seeds]

summarize(results, split="val")
summarize(results, split="test")

summarize_length_sweeps(results, split="val", target_len=20)
summarize_length_sweeps(results, split="test", target_len=20)
# Out:
# /nas/longleaf/home/paulchoi/.local/lib/python3.11/site-packages/torch/nn/modules/transformer.py:408: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(output, src_key_padding_mask.logical_not(), mask_check=False)
# Epoch 01 | train acc 0.5090 | val acc 0.5393
# Epoch 02 | train acc 0.6002 | val acc 0.6346
# Epoch 03 | train acc 0.6471 | val acc 0.6662
# Epoch 04 | train acc 0.6597 | val acc 0.6666
# Epoch 05 | train acc 0.6673 | val acc 0.6784
# Epoch 06 | train acc 0.6773 | val acc 0.6715
# Epoch 07 | train acc 0.6788 | val acc 0.6813
# Epoch 08 | train acc 0.6870 | val acc 0.6930
# Epoch 09 | train acc 0.6921 | val acc 0.7005
# Epoch 10 | train acc 0.6971 | val acc 0.7029
# Epoch 11 | train acc 0.7001 | val acc 0.7054
# Epoch 12 | train acc 0.7044 | val acc 0.6990
# Epoch 13 | train acc 0.7068 | val acc 0.7129
# Epoch 14 | train acc 0.7104 | val acc 0.7046
# Epoch 15 | train acc 0.7130 | val acc 0.7171
# Epoch 16 | train acc 0.7150 | val acc 0.7203
# Epoch 17 | train acc 0.7172 | val acc 0.7182
# Epoch 18 | train acc 0.7188 | val acc 0.7209
# Epoch 19 | train acc 0.7215 | val acc 0.7260
# Epoch 20 | train acc 0.7245 | val acc 0.7094
# Epoch 21 | train acc 0.7273 | val acc 0.7306
# Epoch 22 | train acc 0.7291 | val acc 0.7313
# Epoch 23 | train acc 0.7300 | val acc 0.7348
# Epoch 24 | train acc 0.7323 | val acc 0.7248
# Epoch 25 | train acc 0.7357 | val acc 0.7299
# Epoch 26 | train acc 0.7356 | val acc 0.7286
# Epoch 27 | train acc 0.7388 | val acc 0.7299
# Epoch 28 | train acc 0.7405 | val acc 0.7440
# Epoch 29 | train acc 0.7423 | val acc 0.7422
# Epoch 30 | train acc 0.7447 | val acc 0.7349
# Epoch 31 | train acc 0.7450 | val acc 0.7466
# Epoch 32 | train acc 0.7484 | val acc 0.7414
# Epoch 33 | train acc 0.7489 | val acc 0.7447
# Epoch 34 | train acc 0.7492 | val acc 0.7456
# Epoch 35 | train acc 0.7519 | val acc 0.7521
# Epoch 36 | train acc 0.7527 | val acc 0.7508
# Epoch 37 | train acc 0.7556 | val acc 0.7518
# Epoch 38 | train acc 0.7566 | val acc 0.7512
# Epoch 39 | train acc 0.7584 | val acc 0.7534
# Epoch 40 | train acc 0.7579 | val acc 0.7516
# Epoch 41 | train acc 0.7607 | val acc 0.7503
# Epoch 42 | train acc 0.7623 | val acc 0.7546
# Epoch 43 | train acc 0.7645 | val acc 0.7611
# Epoch 44 | train acc 0.7649 | val acc 0.7604
# Epoch 45 | train acc 0.7677 | val acc 0.7588
# Epoch 46 | train acc 0.7692 | val acc 0.7591
# Epoch 47 | train acc 0.7699 | val acc 0.7568
# Epoch 48 | train acc 0.7699 | val acc 0.7636
# Epoch 49 | train acc 0.7716 | val acc 0.7605
# Epoch 50 | train acc 0.7720 | val acc 0.7615
# Epoch 51 | train acc 0.7740 | val acc 0.7637
# Epoch 52 | train acc 0.7755 | val acc 0.7678
# Epoch 53 | train acc 0.7760 | val acc 0.7654
# Epoch 54 | train acc 0.7777 | val acc 0.7636
# Epoch 55 | train acc 0.7771 | val acc 0.7666
# Epoch 56 | train acc 0.7799 | val acc 0.7684
# Epoch 57 | train acc 0.7814 | val acc 0.7678
# Epoch 58 | train acc 0.7821 | val acc 0.7698
# Epoch 59 | train acc 0.7831 | val acc 0.7660
# Epoch 60 | train acc 0.7843 | val acc 0.7727
# Epoch 61 | train acc 0.7858 | val acc 0.7698
# Epoch 62 | train acc 0.7862 | val acc 0.7687
# Epoch 63 | train acc 0.7875 | val acc 0.7713
# Epoch 64 | train acc 0.7891 | val acc 0.7725
# Epoch 65 | train acc 0.7904 | val acc 0.7729
# Epoch 66 | train acc 0.7918 | val acc 0.7723
# Epoch 67 | train acc 0.7933 | val acc 0.7719
# Epoch 68 | train acc 0.7931 | val acc 0.7788
# Epoch 69 | train acc 0.7941 | val acc 0.7763
# Epoch 70 | train acc 0.7964 | val acc 0.7769
# Epoch 71 | train acc 0.7976 | val acc 0.7790
# Epoch 72 | train acc 0.7992 | val acc 0.7803
# Epoch 73 | train acc 0.7993 | val acc 0.7803
# Epoch 74 | train acc 0.8016 | val acc 0.7880
# Epoch 75 | train acc 0.8029 | val acc 0.7828
# Epoch 76 | train acc 0.8030 | val acc 0.7872
# Epoch 77 | train acc 0.8051 | val acc 0.7834
# Epoch 78 | train acc 0.8066 | val acc 0.7811
# Epoch 79 | train acc 0.8093 | val acc 0.7913
# Epoch 80 | train acc 0.8086 | val acc 0.7898
# Epoch 81 | train acc 0.8101 | val acc 0.7790
# Epoch 82 | train acc 0.8112 | val acc 0.7937
# Epoch 83 | train acc 0.8119 | val acc 0.7881
# Epoch 84 | train acc 0.8136 | val acc 0.7927
# Epoch 85 | train acc 0.8150 | val acc 0.7909
# Epoch 86 | train acc 0.8162 | val acc 0.7972
# Epoch 87 | train acc 0.8169 | val acc 0.7919
# Epoch 88 | train acc 0.8163 | val acc 0.7955
# Epoch 89 | train acc 0.8184 | val acc 0.7929
# Epoch 90 | train acc 0.8184 | val acc 0.7936
# Epoch 91 | train acc 0.8200 | val acc 0.7931
# Epoch 01 | train acc 0.5109 | val acc 0.5646
# Epoch 02 | train acc 0.5955 | val acc 0.6052
# Epoch 03 | train acc 0.6498 | val acc 0.6479
# Epoch 04 | train acc 0.6654 | val acc 0.6707
# Epoch 05 | train acc 0.6726 | val acc 0.6759
# Epoch 06 | train acc 0.6795 | val acc 0.6898
# Epoch 07 | train acc 0.6861 | val acc 0.6850
# Epoch 08 | train acc 0.6869 | val acc 0.6957
# Epoch 09 | train acc 0.6923 | val acc 0.7021
# Epoch 10 | train acc 0.6967 | val acc 0.7066
# Epoch 11 | train acc 0.7021 | val acc 0.6987
# Epoch 12 | train acc 0.7039 | val acc 0.7109
# Epoch 13 | train acc 0.7065 | val acc 0.7127
# Epoch 14 | train acc 0.7120 | val acc 0.7238
# Epoch 15 | train acc 0.7120 | val acc 0.7215
# Epoch 16 | train acc 0.7156 | val acc 0.7231
# Epoch 17 | train acc 0.7172 | val acc 0.7267
# Epoch 18 | train acc 0.7203 | val acc 0.7261
# Epoch 19 | train acc 0.7202 | val acc 0.7234
# Epoch 20 | train acc 0.7256 | val acc 0.7279
# Epoch 21 | train acc 0.7256 | val acc 0.7260
# Epoch 22 | train acc 0.7285 | val acc 0.7368
# Epoch 23 | train acc 0.7304 | val acc 0.7291
# Epoch 24 | train acc 0.7336 | val acc 0.7363
# Epoch 25 | train acc 0.7342 | val acc 0.7364
# Epoch 26 | train acc 0.7346 | val acc 0.7322
# Epoch 27 | train acc 0.7376 | val acc 0.7263
# Epoch 01 | train acc 0.5069 | val acc 0.5495
# Epoch 02 | train acc 0.5757 | val acc 0.6404
# Epoch 03 | train acc 0.6436 | val acc 0.6632
# Epoch 04 | train acc 0.6673 | val acc 0.6845
# Epoch 05 | train acc 0.6774 | val acc 0.6926
# Epoch 06 | train acc 0.6843 | val acc 0.6901
# Epoch 07 | train acc 0.6884 | val acc 0.7051
# Epoch 08 | train acc 0.6939 | val acc 0.7034
# Epoch 09 | train acc 0.6974 | val acc 0.7071
# Epoch 10 | train acc 0.7013 | val acc 0.7064
# Epoch 11 | train acc 0.7047 | val acc 0.7065
# Epoch 12 | train acc 0.7078 | val acc 0.7184
# Epoch 13 | train acc 0.7100 | val acc 0.7168
# Epoch 14 | train acc 0.7126 | val acc 0.7228
# Epoch 15 | train acc 0.7151 | val acc 0.7277
# Epoch 16 | train acc 0.7190 | val acc 0.7204
# Epoch 17 | train acc 0.7212 | val acc 0.7317
# Epoch 18 | train acc 0.7235 | val acc 0.7212
# Epoch 19 | train acc 0.7271 | val acc 0.7319
# Epoch 20 | train acc 0.7282 | val acc 0.7366
# Epoch 21 | train acc 0.7294 | val acc 0.7393
# Epoch 22 | train acc 0.7359 | val acc 0.7408
# Epoch 23 | train acc 0.7356 | val acc 0.7405
# Epoch 24 | train acc 0.7374 | val acc 0.7376
# Epoch 25 | train acc 0.7423 | val acc 0.7384
# Epoch 26 | train acc 0.7424 | val acc 0.7415
# Epoch 27 | train acc 0.7440 | val acc 0.7422
# Epoch 28 | train acc 0.7463 | val acc 0.7503
# Epoch 29 | train acc 0.7471 | val acc 0.7500
# Epoch 30 | train acc 0.7504 | val acc 0.7506
# Epoch 31 | train acc 0.7527 | val acc 0.7473
# Epoch 32 | train acc 0.7540 | val acc 0.7597
# Epoch 33 | train acc 0.7556 | val acc 0.7565
# Epoch 34 | train acc 0.7588 | val acc 0.7589
# Epoch 35 | train acc 0.7581 | val acc 0.7542
# Epoch 36 | train acc 0.7616 | val acc 0.7589
# Epoch 37 | train acc 0.7629 | val acc 0.7578
# Epoch 01 | train acc 0.5128 | val acc 0.5519
# Epoch 02 | train acc 0.5679 | val acc 0.6057
# Epoch 03 | train acc 0.6311 | val acc 0.6671
# Epoch 04 | train acc 0.6571 | val acc 0.6360
# Epoch 05 | train acc 0.6697 | val acc 0.6520
# Epoch 06 | train acc 0.6758 | val acc 0.6874
# Epoch 07 | train acc 0.6836 | val acc 0.6972
# Epoch 08 | train acc 0.6874 | val acc 0.6982
# Epoch 09 | train acc 0.6920 | val acc 0.7032
# Epoch 10 | train acc 0.6944 | val acc 0.7050
# Epoch 11 | train acc 0.7004 | val acc 0.7034
# Epoch 12 | train acc 0.7031 | val acc 0.7056
# Epoch 13 | train acc 0.7065 | val acc 0.7128
# Epoch 14 | train acc 0.7090 | val acc 0.7135
# Epoch 15 | train acc 0.7134 | val acc 0.7229
# Epoch 16 | train acc 0.7161 | val acc 0.7247
# Epoch 17 | train acc 0.7185 | val acc 0.7297
# Epoch 18 | train acc 0.7206 | val acc 0.7275
# Epoch 19 | train acc 0.7241 | val acc 0.7324
# Epoch 20 | train acc 0.7258 | val acc 0.7356
# Epoch 21 | train acc 0.7284 | val acc 0.7373
# Epoch 22 | train acc 0.7302 | val acc 0.7374
# Epoch 23 | train acc 0.7333 | val acc 0.7346
# Epoch 24 | train acc 0.7346 | val acc 0.7318
# Epoch 25 | train acc 0.7359 | val acc 0.7409
# Epoch 26 | train acc 0.7375 | val acc 0.7440
# Epoch 27 | train acc 0.7413 | val acc 0.7428
# Epoch 28 | train acc 0.7432 | val acc 0.7385
# Epoch 29 | train acc 0.7442 | val acc 0.7510
# Epoch 30 | train acc 0.7445 | val acc 0.7484
# Epoch 31 | train acc 0.7487 | val acc 0.7476
# Epoch 32 | train acc 0.7509 | val acc 0.7428
# Epoch 33 | train acc 0.7522 | val acc 0.7453
# Epoch 34 | train acc 0.7543 | val acc 0.7539
# Epoch 35 | train acc 0.7555 | val acc 0.7562
# Epoch 36 | train acc 0.7573 | val acc 0.7619
# Epoch 37 | train acc 0.7611 | val acc 0.7602
# Epoch 38 | train acc 0.7622 | val acc 0.7567
# Epoch 39 | train acc 0.7659 | val acc 0.7664
# Epoch 40 | train acc 0.7678 | val acc 0.7456
# Epoch 41 | train acc 0.7699 | val acc 0.7688
# Epoch 42 | train acc 0.7721 | val acc 0.7721
# Epoch 43 | train acc 0.7750 | val acc 0.7741
# Epoch 44 | train acc 0.7759 | val acc 0.7748
# Epoch 45 | train acc 0.7793 | val acc 0.7790
# Epoch 46 | train acc 0.7801 | val acc 0.7753
# Epoch 47 | train acc 0.7816 | val acc 0.7777
# Epoch 48 | train acc 0.7838 | val acc 0.7760
# Epoch 49 | train acc 0.7850 | val acc 0.7812
# Epoch 50 | train acc 0.7865 | val acc 0.7855
# Epoch 51 | train acc 0.7871 | val acc 0.7844
# Epoch 52 | train acc 0.7880 | val acc 0.7838
# Epoch 53 | train acc 0.7906 | val acc 0.7825
# Epoch 54 | train acc 0.7912 | val acc 0.7843
# Epoch 55 | train acc 0.7932 | val acc 0.7806
# Epoch 01 | train acc 0.5095 | val acc 0.5500
# Epoch 02 | train acc 0.6083 | val acc 0.6420
# Epoch 03 | train acc 0.6541 | val acc 0.6795
# Epoch 04 | train acc 0.6670 | val acc 0.6808
# Epoch 05 | train acc 0.6767 | val acc 0.6920
# Epoch 06 | train acc 0.6824 | val acc 0.6997
# Epoch 07 | train acc 0.6886 | val acc 0.6945
# Epoch 08 | train acc 0.6945 | val acc 0.7043
# Epoch 09 | train acc 0.6987 | val acc 0.6999
# Epoch 10 | train acc 0.7008 | val acc 0.7099
# Epoch 11 | train acc 0.7047 | val acc 0.7141
# Epoch 12 | train acc 0.7088 | val acc 0.7112
# Epoch 13 | train acc 0.7114 | val acc 0.7169
# Epoch 14 | train acc 0.7139 | val acc 0.7231
# Epoch 15 | train acc 0.7164 | val acc 0.7215
# Epoch 16 | train acc 0.7198 | val acc 0.7263
# Epoch 17 | train acc 0.7207 | val acc 0.7269
# Epoch 18 | train acc 0.7242 | val acc 0.7277
# Epoch 19 | train acc 0.7261 | val acc 0.7363
# Epoch 20 | train acc 0.7285 | val acc 0.7186
# Epoch 21 | train acc 0.7293 | val acc 0.7337
# Epoch 22 | train acc 0.7319 | val acc 0.7366
# Epoch 23 | train acc 0.7356 | val acc 0.7359
# Epoch 24 | train acc 0.7359 | val acc 0.7433
# Epoch 25 | train acc 0.7371 | val acc 0.7398
# Epoch 26 | train acc 0.7408 | val acc 0.7361
# Epoch 27 | train acc 0.7409 | val acc 0.7454
# Epoch 28 | train acc 0.7423 | val acc 0.7488
# Epoch 29 | train acc 0.7464 | val acc 0.7437
# Epoch 30 | train acc 0.7485 | val acc 0.7491
# Epoch 31 | train acc 0.7498 | val acc 0.7472
# Epoch 32 | train acc 0.7507 | val acc 0.7503
# Epoch 33 | train acc 0.7517 | val acc 0.7507
# Epoch 34 | train acc 0.7535 | val acc 0.7475
# Epoch 35 | train acc 0.7563 | val acc 0.7531
# Epoch 36 | train acc 0.7566 | val acc 0.7566
# Epoch 37 | train acc 0.7584 | val acc 0.7596
# Epoch 38 | train acc 0.7594 | val acc 0.7619
# Epoch 39 | train acc 0.7617 | val acc 0.7633
# Epoch 40 | train acc 0.7620 | val acc 0.7550
# Epoch 41 | train acc 0.7650 | val acc 0.7605
# Epoch 42 | train acc 0.7668 | val acc 0.7646
# Epoch 43 | train acc 0.7674 | val acc 0.7659
# Epoch 44 | train acc 0.7699 | val acc 0.7655
# Epoch 45 | train acc 0.7694 | val acc 0.7645
# Epoch 46 | train acc 0.7711 | val acc 0.7631
# Epoch 47 | train acc 0.7722 | val acc 0.7662
# Epoch 48 | train acc 0.7744 | val acc 0.7711
# Epoch 49 | train acc 0.7752 | val acc 0.7712
# Epoch 50 | train acc 0.7762 | val acc 0.7716
# Epoch 51 | train acc 0.7777 | val acc 0.7736
# Epoch 52 | train acc 0.7799 | val acc 0.7745
# Epoch 53 | train acc 0.7796 | val acc 0.7725
# Epoch 54 | train acc 0.7827 | val acc 0.7757
# Epoch 55 | train acc 0.7815 | val acc 0.7639
# Epoch 56 | train acc 0.7834 | val acc 0.7762
# Epoch 57 | train acc 0.7840 | val acc 0.7780
# Epoch 58 | train acc 0.7854 | val acc 0.7768
# Epoch 59 | train acc 0.7866 | val acc 0.7743
# Epoch 60 | train acc 0.7884 | val acc 0.7822
# Epoch 61 | train acc 0.7887 | val acc 0.7811
# Epoch 62 | train acc 0.7897 | val acc 0.7785
# Epoch 63 | train acc 0.7920 | val acc 0.7825
# Epoch 64 | train acc 0.7933 | val acc 0.7831
# Epoch 65 | train acc 0.7933 | val acc 0.7866
# Epoch 66 | train acc 0.7939 | val acc 0.7877
# Epoch 67 | train acc 0.7935 | val acc 0.7862
# Epoch 68 | train acc 0.7965 | val acc 0.7833
# Epoch 69 | train acc 0.7982 | val acc 0.7848
# Epoch 70 | train acc 0.7964 | val acc 0.7883
# Epoch 71 | train acc 0.7996 | val acc 0.7875
# Epoch 72 | train acc 0.8001 | val acc 0.7782
# Epoch 73 | train acc 0.8002 | val acc 0.7906
# Epoch 74 | train acc 0.8026 | val acc 0.7852
# Epoch 75 | train acc 0.8028 | val acc 0.7863
# Epoch 76 | train acc 0.8045 | val acc 0.7899
# Epoch 77 | train acc 0.8046 | val acc 0.7938
# Epoch 78 | train acc 0.8072 | val acc 0.7947
# Epoch 79 | train acc 0.8061 | val acc 0.7928
# Epoch 80 | train acc 0.8090 | val acc 0.7931
# Epoch 81 | train acc 0.8097 | val acc 0.7922
# Epoch 82 | train acc 0.8090 | val acc 0.7921
# Epoch 83 | train acc 0.8102 | val acc 0.7939
#
# === Per-run VAL metrics + inference time ===
# seed=0 | acc=0.7972 | macro_f1=0.7961 | weighted_f1=0.7964 | infer_time=0.404s | per_sample=0.014ms
# seed=1 | acc=0.7368 | macro_f1=0.7351 | weighted_f1=0.7353 | infer_time=0.391s | per_sample=0.014ms
# seed=2 | acc=0.7597 | macro_f1=0.7590 | weighted_f1=0.7590 | infer_time=0.701s | per_sample=0.025ms
# seed=3 | acc=0.7855 | macro_f1=0.7831 | weighted_f1=0.7833 | infer_time=0.378s | per_sample=0.014ms
# seed=4 | acc=0.7947 | macro_f1=0.7942 | weighted_f1=0.7944 | infer_time=0.377s | per_sample=0.013ms
#
# === TRAIN time Mean ± Std over 5 runs ===
# train_time_s      : 701.849 ± 342.382
#
# === VAL Mean ± Std over 5 runs ===
# acc             : 0.7748 ± 0.0259
# macro_f1        : 0.7735 ± 0.0261
# weighted_f1     : 0.7737 ± 0.0261
# macro_precision : 0.7741 ± 0.0258
# macro_recall    : 0.7743 ± 0.0260
#
# === VAL INFERENCE time Mean ± Std over 5 runs ===
# infer_time_s      : 0.450 ± 0.141
# per_sample_ms     : 0.016 ± 0.005
#
# VAL confusion matrix mean:
#  [[5567.   178.4 1000.8  169.8]
#  [ 190.4 4771.6  733.8  976.2]
#  [1029.6  746.8 5128.2  355.4]
#  [ 103.4  648.6  169.  6214. ]]
#
# VAL confusion matrix std:
#  [[232.78530881  15.40454478 204.52310383  48.75653802]
#  [ 57.23023676 225.6796402  116.42250642 128.12376829]
#  [168.73292506  90.41404758 237.1206444   69.48956756]
#  [ 38.12872933 101.88621104  70.05355094 149.08051516]]
#
# === Per-run TEST metrics + inference time ===
# seed=0 | acc=0.7948 | macro_f1=0.7867 | weighted_f1=0.7958 | infer_time=0.845s | per_sample=0.013ms
# seed=1 | acc=0.7548 | macro_f1=0.7445 | weighted_f1=0.7544 | infer_time=0.857s | per_sample=0.014ms
# seed=2 | acc=0.7690 | macro_f1=0.7606 | weighted_f1=0.7702 | infer_time=0.860s | per_sample=0.014ms
# seed=3 | acc=0.7825 | macro_f1=0.7721 | weighted_f1=0.7824 | infer_time=0.992s | per_sample=0.016ms
# seed=4 | acc=0.7889 | macro_f1=0.7819 | weighted_f1=0.7901 | infer_time=0.836s | per_sample=0.013ms
#
# === TRAIN time Mean ± Std over 5 runs ===
# train_time_s      : 701.849 ± 342.382
#
# === TEST Mean ± Std over 5 runs ===
# acc             : 0.7780 ± 0.0161
# macro_f1        : 0.7692 ± 0.0170
# weighted_f1     : 0.7786 ± 0.0166
# macro_precision : 0.7693 ± 0.0170
# macro_recall    : 0.7696 ± 0.0171
#
# === TEST INFERENCE time Mean ± Std over 5 runs ===
# infer_time_s      : 0.878 ± 0.064
# per_sample_ms     : 0.014 ± 0.001
#
# TEST confusion matrix mean:
#  [[10583.6   440.2  1969.4   467.8]
#  [  612.  10595.4  2116.4  1278.2]
#  [ 2041.6  1493.  10185.2   694.2]
#  [  315.   1974.    591.2 17682.8]]
#
# TEST confusion matrix std:
#  [[256.4123632   93.91325785 105.30337127 198.9678366 ]
#  [131.12589371 431.01832908 271.20158554 208.06657588]
#  [289.80648716 194.33604915 410.44816969 130.42890784]
#  [117.5329741  146.10099247 192.85668254 283.11428788]]
#
# === VAL Length Sweep Mean ± Std ===
# k= 2 | coverage=1.0000±0.0000 | acc=0.7748±0.0259 | macro_f1=0.7735±0.0261 | weighted_f1=0.7737±0.0261
# k= 3 | coverage=0.9829±0.0000 | acc=0.7800±0.0261 | macro_f1=0.7787±0.0261 | weighted_f1=0.7789±0.0261
# k= 4 | coverage=0.9798±0.0000 | acc=0.7808±0.0261 | macro_f1=0.7795±0.0261 | weighted_f1=0.7797±0.0261
# k= 5 | coverage=0.9756±0.0000 | acc=0.7815±0.0260 | macro_f1=0.7801±0.0261 | weighted_f1=0.7803±0.0261
# k= 6 | coverage=0.9586±0.0000 | acc=0.7793±0.0264 | macro_f1=0.7787±0.0264 | weighted_f1=0.7782±0.0265
# k= 7 | coverage=0.9459±0.0000 | acc=0.7799±0.0264 | macro_f1=0.7793±0.0264 | weighted_f1=0.7788±0.0265
# k= 8 | coverage=0.9251±0.0000 | acc=0.7810±0.0263 | macro_f1=0.7804±0.0262 | weighted_f1=0.7800±0.0263
# k= 9 | coverage=0.9057±0.0000 | acc=0.7818±0.0262 | macro_f1=0.7813±0.0261 | weighted_f1=0.7808±0.0262
# k=10 | coverage=0.8766±0.0000 | acc=0.7831±0.0263 | macro_f1=0.7825±0.0262 | weighted_f1=0.7820±0.0264
# k=11 | coverage=0.8244±0.0000 | acc=0.7843±0.0265 | macro_f1=0.7839±0.0264 | weighted_f1=0.7833±0.0266
# k=12 | coverage=0.7718±0.0000 | acc=0.7877±0.0265 | macro_f1=0.7872±0.0264 | weighted_f1=0.7867±0.0266
# k=13 | coverage=0.7241±0.0000 | acc=0.7906±0.0266 | macro_f1=0.7899±0.0265 | weighted_f1=0.7897±0.0267
# k=14 | coverage=0.6795±0.0000 | acc=0.7943±0.0263 | macro_f1=0.7935±0.0261 | weighted_f1=0.7934±0.0264
# k=15 | coverage=0.6333±0.0000 | acc=0.7969±0.0257 | macro_f1=0.7960±0.0255 | weighted_f1=0.7960±0.0258
# k=16 | coverage=0.5826±0.0000 | acc=0.8003±0.0257 | macro_f1=0.7991±0.0254 | weighted_f1=0.7995±0.0257
# k=17 | coverage=0.5277±0.0000 | acc=0.8032±0.0255 | macro_f1=0.8017±0.0251 | weighted_f1=0.8024±0.0255
# k=18 | coverage=0.4759±0.0000 | acc=0.8031±0.0254 | macro_f1=0.8012±0.0250 | weighted_f1=0.8023±0.0254
# k=19 | coverage=0.4303±0.0000 | acc=0.8035±0.0255 | macro_f1=0.8017±0.0250 | weighted_f1=0.8028±0.0254
# k=20 | coverage=0.3902±0.0000 | acc=0.8025±0.0250 | macro_f1=0.8006±0.0246 | weighted_f1=0.8019±0.0250
#
# === TEST Length Sweep Mean ± Std ===
# k= 2 | coverage=1.0000±0.0000 | acc=0.7780±0.0161 | macro_f1=0.7692±0.0170 | weighted_f1=0.7786±0.0166
# k= 3 | coverage=0.9767±0.0000 | acc=0.7854±0.0173 | macro_f1=0.7769±0.0181 | weighted_f1=0.7857±0.0175
# k= 4 | coverage=0.9675±0.0000 | acc=0.7882±0.0180 | macro_f1=0.7798±0.0186 | weighted_f1=0.7883±0.0181
# k= 5 | coverage=0.9600±0.0000 | acc=0.7896±0.0182 | macro_f1=0.7815±0.0187 | weighted_f1=0.7897±0.0183
# k= 6 | coverage=0.9102±0.0000 | acc=0.7805±0.0192 | macro_f1=0.7774±0.0194 | weighted_f1=0.7806±0.0193
# k= 7 | coverage=0.8961±0.0000 | acc=0.7823±0.0192 | macro_f1=0.7791±0.0194 | weighted_f1=0.7824±0.0193
# k= 8 | coverage=0.8758±0.0000 | acc=0.7832±0.0190 | macro_f1=0.7801±0.0192 | weighted_f1=0.7832±0.0190
# k= 9 | coverage=0.8583±0.0000 | acc=0.7843±0.0189 | macro_f1=0.7813±0.0190 | weighted_f1=0.7844±0.0189
# k=10 | coverage=0.8285±0.0000 | acc=0.7860±0.0189 | macro_f1=0.7831±0.0190 | weighted_f1=0.7860±0.0189
# k=11 | coverage=0.7761±0.0000 | acc=0.7879±0.0188 | macro_f1=0.7851±0.0190 | weighted_f1=0.7879±0.0189
# k=12 | coverage=0.7250±0.0000 | acc=0.7916±0.0190 | macro_f1=0.7889±0.0193 | weighted_f1=0.7918±0.0192
# k=13 | coverage=0.6789±0.0000 | acc=0.7943±0.0189 | macro_f1=0.7915±0.0192 | weighted_f1=0.7945±0.0190
# k=14 | coverage=0.6326±0.0000 | acc=0.7968±0.0189 | macro_f1=0.7941±0.0191 | weighted_f1=0.7971±0.0189
# k=15 | coverage=0.5866±0.0000 | acc=0.7985±0.0190 | macro_f1=0.7959±0.0192 | weighted_f1=0.7988±0.0191
# k=16 | coverage=0.5372±0.0000 | acc=0.8016±0.0194 | macro_f1=0.7992±0.0196 | weighted_f1=0.8019±0.0194
# k=17 | coverage=0.4838±0.0000 | acc=0.8035±0.0195 | macro_f1=0.8009±0.0196 | weighted_f1=0.8039±0.0195
# k=18 | coverage=0.4353±0.0000 | acc=0.8040±0.0193 | macro_f1=0.8013±0.0195 | weighted_f1=0.8044±0.0194
# k=19 | coverage=0.3923±0.0000 | acc=0.8043±0.0189 | macro_f1=0.8016±0.0191 | weighted_f1=0.8049±0.0190
# k=20 | coverage=0.3566±0.0000 | acc=0.8023±0.0191 | macro_f1=0.7999±0.0192 | weighted_f1=0.8030±0.0191
